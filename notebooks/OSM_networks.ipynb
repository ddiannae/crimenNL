# %%
import networkx as nx
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import geopandas as gpd

# %% [markdown]
# # Deal with the geopandas shapefile

# %%
GEO = "../shape/nuevo_leon.shp"
MUN = "../data/municipios.txt"

# %%
municipios = np.genfromtxt("../data/municipios.txt",
                          delimiter="\t", dtype='unicode')

# %%
shape = gpd.read_file(GEO, encoding='utf-8')
shape = shape[shape.MUN_NAME.isin(municipios)]

# %%
shape.plot(facecolor="blue")

# %%
shape.geometry.head()
# Out:
# 69    POLYGON Z ((-100.1815799997171 25.785799999670...
# 70    POLYGON Z ((-100.1818199999929 25.779610000201...
# 71    POLYGON Z ((-100.1814000004096 25.779840000016...
# 72    POLYGON Z ((-100.1792700002102 25.790200000230...
# 73    POLYGON Z ((-100.2009699999654 25.774099999715...
# Name: geometry, dtype: object

# %% [markdown]
# # Outline
#
# Here, we create several kinds of networks.
#
# - neighborhood network
# - bipartite network (crimes, urban environment)
