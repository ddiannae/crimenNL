# %% [markdown]
# ####  Datos de shapes descargados de:
# https://www.inegi.org.mx/app/mapas/
# http://internet.contenidos.inegi.org.mx/contenidos/Productos/prod_serv/contenidos/espanol/bvinegi/productos/geografia/CGURA_Junio2016/Nuevo_Leon/702825218867_s.zip

# %% [markdown]
# ## Importar data frames

# %%
import pandas as pd
from functools import partial
from pyproj import Proj, transform

# %%
df = pd.read_csv("data/crime_inegi.csv")

# %%
df.head()
# Out:
#    year        date        lat         lon  \
# 0  2015  2015-10-12  25.617672 -100.259318
# 1  2015  2015-10-02  25.632075 -100.286088
# 2  2015  2015-10-01  25.675784 -100.475788
# 3  2015  2015-09-24  25.657586 -100.322029
# 4  2015  2015-09-24  25.683207 -100.305650
#
#                                     news  cassualties  \
# 0          Persiguen y ejecutan a hombre          1.0
# 1  Ejecutan a uno en plaza en Garza Sada          1.0
# 2           Lo ejecutan frente a su casa          1.0
# 3             Lo esperan para ejecutarlo          1.0
# 4  Matan a 2 clientes en ataque 13 a bar          2.0
#
#                                                  url  \
# 0  http://www.elnorte.com/aplicaciones/articulo/d...
# 1  http://www.elnorte.com/aplicaciones/articulo/d...
# 2  http://www.elnorte.com/aplicaciones/articulo/d...
# 3  http://www.elnorte.com/aplicaciones/articulo/d...
# 4  http://www.elnorte.com/aplicaciones/articulo/d...
#
#                        neighborhood                                     point  \
# 0                EJIDAL LOS REMATES   [2673990.068792671, 1508739.2403134028]
# 1             REVOLUCION PROLETARIA   [2671295.4132258967, 1510294.803596502]
# 2  HDA SANTA CATARINA (FOMERREY 29)  [2652285.5673206407, 1514899.6189773784]
# 3                     INDEPENDENCIA   [2667670.5901743174, 1513064.839283476]
# 4               CENTRO DE MONTERREY  [2669273.8077375377, 1515908.7290589423]
#
#    clave_mun         nom_mun  clave_loc                nom_loc  ageb
# 0       39.0       Monterrey        1.0              Monterrey  3729
# 1       39.0       Monterrey        1.0              Monterrey  4727
# 2       48.0  Santa Catarina        1.0  Ciudad Santa Catarina  0545
# 3       39.0       Monterrey        1.0              Monterrey  1968
# 4       39.0       Monterrey        1.0              Monterrey  1281

# %%
print(df.shape)
# Out:
# (2114, 14)

# %%
df.dtypes
# Out:
# year              int64
# date             object
# lat             float64
# lon             float64
# news             object
# cassualties     float64
# url              object
# neighborhood     object
# point            object
# clave_mun       float64
# nom_mun          object
# clave_loc       float64
# nom_loc          object
# ageb             object
# dtype: object

# %%
df["point"] = df["point"].str.replace("[", "")
df["point"] = df["point"].str.replace("]", "")
df["point"] = df["point"].str.split(',')
df["x"] = df["point"].str[0].astype(float)
df["y"] = df["point"].str[1].astype(float)

# %% [markdown]
# ## Mapear a shapes de INEGI

# %%
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import shapefile as shp

# %% [markdown]
# #### Los archivos que terminan en a se refieren a: Área geoestadística básica

# %%
sf = shp.Reader("data/inegi_NL_2016/conjunto_de_datos/19l", encoding="latin1")

# %%
print(sf)
# Out:
# shapefile Reader
#     945 shapes (type 'POLYGON')
#     945 records (7 fields)

# %% [markdown]
# #### Son 945 Localidades

# %%
s = sf.shape(0)
['%.3f' % coord for coord in s.bbox]
# Out:
# ['2674785.542', '1275446.771', '2675346.485', '1276102.915']

# %%
sf.fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['CVE_ENT', 'C', 2, 0],
#  ['CVE_MUN', 'C', 3, 0],
#  ['CVE_LOC', 'C', 4, 0],
#  ['NOMLOC', 'C', 110, 0],
#  ['TIPO', 'C', 6, 0],
#  ['CONDICION', 'C', 11, 0]]

# %%
sf.record(0)
# Out:
# Record #0: ['19', '036', '0021', 'San José de Cuatro Caminos', 'R', 'H']

# %%
paths = [Path(sf.shape(i).points) for i in range(len(sf.shapes())) ]

# %%
paths[0].contains_point((2690417.3087897752, 1512217.7368954867))
# Out:
# False

# %%
def point_in_path(row):
    for i in range(len(paths)):
        if(paths[i].contains_point([row["x"], row["y"]])):
            return i

# %%
def getRecord(r, j):
    if not np.isnan(r):
        if j != 3:
            return int(sf.record(int(r))[j])
        else:
            return sf.record(int(r))[j]
    else:
        return np.nan

# %% [markdown]
# #### Ahora sí con df

# %%
df["r"] = df.apply(point_in_path, axis = 1)

# %%
df.head()
# Out:
#    year        date        lat         lon  \
# 0  2015  2015-10-12  25.617672 -100.259318
# 1  2015  2015-10-02  25.632075 -100.286088
# 2  2015  2015-10-01  25.675784 -100.475788
# 3  2015  2015-09-24  25.657586 -100.322029
# 4  2015  2015-09-24  25.683207 -100.305650
#
#                                     news  cassualties  \
# 0          Persiguen y ejecutan a hombre          1.0
# 1  Ejecutan a uno en plaza en Garza Sada          1.0
# 2           Lo ejecutan frente a su casa          1.0
# 3             Lo esperan para ejecutarlo          1.0
# 4  Matan a 2 clientes en ataque 13 a bar          2.0
#
#                                                  url  \
# 0  http://www.elnorte.com/aplicaciones/articulo/d...
# 1  http://www.elnorte.com/aplicaciones/articulo/d...
# 2  http://www.elnorte.com/aplicaciones/articulo/d...
# 3  http://www.elnorte.com/aplicaciones/articulo/d...
# 4  http://www.elnorte.com/aplicaciones/articulo/d...
#
#                        neighborhood  \
# 0                EJIDAL LOS REMATES
# 1             REVOLUCION PROLETARIA
# 2  HDA SANTA CATARINA (FOMERREY 29)
# 3                     INDEPENDENCIA
# 4               CENTRO DE MONTERREY
#
#                                        point  clave_mun         nom_mun  \
# 0   [2673990.068792671,  1508739.2403134028]       39.0       Monterrey
# 1   [2671295.4132258967,  1510294.803596502]       39.0       Monterrey
# 2  [2652285.5673206407,  1514899.6189773784]       48.0  Santa Catarina
# 3   [2667670.5901743174,  1513064.839283476]       39.0       Monterrey
# 4  [2669273.8077375377,  1515908.7290589423]       39.0       Monterrey
#
#    clave_loc                nom_loc  ageb             x             y     r
# 0        1.0              Monterrey  3729  2.673990e+06  1.508739e+06  75.0
# 44  2015  2015-04-27  25.656503 -100.324078
# 45  2015  2015-04-26  25.621569 -100.264578
# 46  2015  2015-04-16  25.765005 -100.381143
# 47  2015  2015-04-06  25.739612 -100.349349
# 48  2015  2015-04-15  25.819970 -100.296179
# 49  2015  2015-04-20  25.926778 -100.368560
#
#                                              news  cassualties  \
# 0                   Persiguen y ejecutan a hombre          1.0
# 1           Ejecutan a uno en plaza en Garza Sada          1.0
# 2                    Lo ejecutan frente a su casa          1.0
# 3                      Lo esperan para ejecutarlo          1.0
# 4           Matan a 2 clientes en ataque 13 a bar          2.0
# 5               Asesinan a ex reo de tres balazos          1.0
# 6           Ejecutan a uno en la Col. Garza Nieto          1.0
# 7          Ejecutan a joven tras persecuci&#243;n          1.0
# 8            Lo acribillan desde un veh&#237;culo          1.0
# 9     Torturan y ejecutan a dos en Pesquer&#237;a          2.0
# 10           Torturan ejecutan y lo tiran de taxi          1.0
# 11    Hallan a ejecutado en brecha de Garc&#237;a          1.0
# 12                    Indagan muerte de un hombre          1.0
# 13               Ejecutan a trailero en Cadereyta          1.0
# 14              Muere taxista baleado en hospital          1.0
# 15             Le cierran el paso y lo acribillan          1.0
# 16                Acribillan a pareja y a su hijo          3.0
# 17         Muere quemado; ten&#237;a antecedentes          1.0
# 18                  Abaten a ladr&#243;n de autos          1.0
# 19       Hallan a asesinado en Ciudad Solidaridad          1.0
# 20                    Ejecutan a guardia de table          1.0
# 21               Paseaba al perro cuando lo matan          1.0
# 22           Ejecutan a cliente de un restaurante          1.0
# 23                     Ejecutan a menor a balazos          1.0
# 24          Dejan a ejecutado en camioneta robada          1.0
# 25      Hallan ejecutado a ladr&#243;n en Apodaca          1.0
# 26          Dan a tr&#225;nsito el tiro de gracia          1.0
# 27             Ejecutan a pap&#225; de comandante          1.0
# 28               Ejecutan a menor de 14 a&#241;os          1.0
# 29          Ejecutan a un joven al tercer intento          1.0
# 30                      Lo ejecutan tras patearlo          1.0
# 31           Ejecutan a 2 en Pablo A. de la Garza          2.0
# 32             Acribillan a tortillero en Apodaca          1.0
# 33                Lo asesinan desde una camioneta          1.0
# 34                 Torturan y ejecutan a un joven          1.0
# 35            Encuentran en llamas a un ejecutado          1.0
# 36         Encuentran a un ejecutado en Guadalupe          1.0
# 37       Hallan a hombre ejecutado en Garc&#237;a          1.0
# 38            Ejecutan a hombre en Santa Catarina          1.0
# 39      Lo matan a 3 d&#237;as de salir del Penal          1.0
# 40  Calientan Cadereyta balacera y ejecuci&#243;n          1.0
# 41                Hallan cad&#225;ver de soldador          1.0
# 42        Hallan en 3 bolsas cuerpo descuartizado          1.0
# 43                 Disparan desde taxi; matan a 1          1.0
# 44          Fallece menor de 12 a&#241;os baleado          1.0
# 45  Disparan contra j&#243;venes y ejecutan a uno          1.0
# 46              Cazan sicarios a dos j&#243;venes          2.0
# 47             Acribillan sicarios a 3 en 6 horas          3.0
# 49  http://www.elnorte.com/aplicaciones/articulo/d...
#
#                           neighborhood  \
# 0                   EJIDAL LOS REMATES
# 1                REVOLUCION PROLETARIA
# 2     HDA SANTA CATARINA (FOMERREY 29)
# 3                        INDEPENDENCIA
# 4                  CENTRO DE MONTERREY
# 5                           LA ALIANZA
# 6                         PEDRO LOZANO
# 7                 NOGALES DE LA SIERRA
# 8                         NUEVA MADERO
# 9                                  NaN
# 10               FOMERREY AMPL NOGALES
# 11                          LAS PALMAS
# 12                                 NaN
# 13                                 NaN
# 14                       MONTE KRISTAL
# 15                           MOCTEZUMA
# 16                FRANCISCO GARZA SADA
# 17                          INDUSTRIAL
# 18                             MODERNA
# 19                   BARRIO TOPO CHICO
# 20                        FOMERREY 110
# 21                   AVANCE PROLETARIO
# 22               DEL PASEO RESIDENCIAL
# 23                          INDUSTRIAL
# 24                      VALLE LA SILLA
# 25                  FRANCISCO ELIZONDO
# 26                      ESTACION LEONA
# 27                                 NaN
# 28                                 NaN
# 29                       INDEPENDENCIA
# 30                         TOPO GRANDE
# 31                            FABRILES
# 32                      APODACA CENTRO
# 33                               SANCA
# 34            EMILIANO ZAPATA 2DO SECT
# 35                    20 DE SEPTIEMBRE
# 36                      PUERTA DEL SOL
# 37                              CENTRO
# 38                               SANCA
# 39                               SANCA
# 40            EMILIANO ZAPATA 2DO SECT
# 41            EMILIANO ZAPATA 2DO SECT
# 42          HECTOR CABALLERO ESCAMILLA
# 43  CONSTITUYENTES DE QUERETARO SECT 2
# 44                       INDEPENDENCIA
# 45                  EJIDAL LOS REMATES
# 46                        FOMERREY 116
# 47                VALLE DE SANTA LUCIA
# 48                      RAUL CABALLERO
# 49                                 NaN
#
#                                         point  clave_mun  \
# 0    [2673990.068792671,  1508739.2403134028]       39.0
# 1    [2671295.4132258967,  1510294.803596502]       39.0
# 2   [2652285.5673206407,  1514899.6189773784]       48.0
# 3    [2667670.5901743174,  1513064.839283476]       39.0
# 4   [2669273.8077375377,  1515908.7290589423]       39.0
# 5    [2658693.510923911,  1526191.7772835381]       39.0
# 6   [2666732.2379076034,  1517993.7998131234]       39.0
# 7   [2676417.3226552834,  1505141.5785776984]       39.0
# 8    [2671791.048815214,  1516836.2648395365]       39.0
# 9     [2694271.730618012,  1529215.312199961]        NaN
# 10   [2639310.146071647,  1528762.1548491854]       18.0
# 11  [2657442.7938923123,  1527618.2289961304]       18.0
# 12  [2636313.1972550275,  1531440.7240590043]        NaN
# 13   [2699215.2362968083,  1501365.631973552]        NaN
# 14  [2685802.6372228544,  1508801.5918838056]       31.0
# 15  [2665196.9304710133,  1521529.9055522627]       39.0
# 16  [2672857.4609076516,  1518705.6124618633]       39.0
# 17  [2667508.2114782184,  1516328.8132398087]       39.0
# 18   [2671677.8458500854,  1518376.616800545]       39.0
# 19   [2661549.2497044187,  1527272.401770735]       39.0
# 20  [2661152.3286900693,  1524254.7690005484]       39.0
# 21  [2667322.0247764387,  1521011.3948960232]       39.0
# 22  [2669971.7183558056,  1509563.1762432707]       39.0
# 23   [2667874.3623278476,  1516697.411837462]       39.0
# 24  [2678480.7485439107,  1512958.1142630894]       26.0
# 25   [2676088.1901707607,  1524464.393851654]        6.0
# 26      [2657881.5243153,  1514818.388778557]       19.0
# 27  [2688660.1126179844,  1488612.4465364714]        NaN
# 28  [2698847.5903887223,  1502806.0942648053]        NaN
# 29    [2667327.65088753,  1512984.9710354167]       39.0
# 30   [2668118.4475613167,  1526914.776025994]       21.0
# 31  [2671796.8506253585,  1516352.4160838993]       39.0
# 32  [2680930.1880442672,  1526896.7344802401]        6.0
# 33  [2653714.8243133035,  1514116.2008929935]       48.0
# 34   [2697511.539771348,  1505540.1046013376]        9.0
# 35  [2689272.7200636384,  1512679.0315981081]       31.0
# 36    [2685816.60009743,  1514871.5465880786]       26.0
# 37  [2640734.0059646545,  1529501.7414611664]       18.0
# 38  [2653714.8243133035,  1514116.2008929935]       48.0
# 39  [2653714.8243133035,  1514116.2008929935]       48.0
# 40   [2697511.539771348,  1505540.1046013376]        9.0
# 41   [2697511.539771348,  1505540.1046013376]        9.0
# 42   [2687161.3337405543,  1510964.278906798]       31.0
# 43    [2673586.525989117,  1519593.475592558]       46.0
# 44  [2667467.2492520544,  1512943.0484499442]       39.0
# 45   [2673459.1318512233,  1509162.484300077]       39.0
# 46  [2661630.2168715512,  1524840.0662123798]       39.0
# 47  [2664836.6843392826,  1522076.5445977927]       39.0
# 48   [2670040.8189135017,  1530998.668689603]       21.0
# 49   [2662683.559293736,  1542691.9919759312]        NaN
#
#                      nom_mun  clave_loc                          nom_loc  \
# 0                  Monterrey        1.0                        Monterrey
# 1                  Monterrey        1.0                        Monterrey
# 2             Santa Catarina        1.0            Ciudad Santa Catarina
# 3                  Monterrey        1.0                        Monterrey
# 4                  Monterrey        1.0                        Monterrey
# 5                  Monterrey        1.0                        Monterrey
# 6                  Monterrey        1.0                        Monterrey
# 7                  Monterrey        1.0                        Monterrey
# 8                  Monterrey        1.0                        Monterrey
# 9                        NaN        NaN                              NaN
# 10                    García        1.0                           García
# 11                    García      105.0  Parque Industrial Ciudad Mitras
# 12                       NaN        NaN                              NaN
# 13                       NaN        NaN                              NaN
# 14                    Juárez      313.0           Arboledas de San Roque
# 15                 Monterrey        1.0                        Monterrey
# 16                 Monterrey        1.0                        Monterrey
# 17                 Monterrey        1.0                        Monterrey
# 18                 Monterrey        1.0                        Monterrey
# 19                 Monterrey        1.0                        Monterrey
# 20                 Monterrey        1.0                        Monterrey
# 21                 Monterrey        1.0                        Monterrey
# 22                 Monterrey        1.0                        Monterrey
# 23                 Monterrey        1.0                        Monterrey
# 24                 Guadalupe        1.0                        Guadalupe
# 25                   Apodaca        1.0                   Ciudad Apodaca
# 26    San Pedro Garza García        1.0           San Pedro Garza García
# 25  0174  2.676088e+06  1.524464e+06   72.0      6.0      1.0
# 26  0577  2.657882e+06  1.514818e+06  562.0     19.0      1.0
# 27   NaN  2.688660e+06  1.488612e+06    NaN      NaN      NaN
# 28   NaN  2.698848e+06  1.502806e+06    NaN      NaN      NaN
# 29  1953  2.667328e+06  1.512985e+06   75.0     39.0      1.0
# 30  0575  2.668118e+06  1.526915e+06  565.0     21.0      1.0
# 31  1347  2.671797e+06  1.516352e+06   75.0     39.0      1.0
# 32  0085  2.680930e+06  1.526897e+06   72.0      6.0      1.0
# 33  0263  2.653715e+06  1.514116e+06   70.0     48.0      1.0
# 34  098A  2.697512e+06  1.505540e+06  375.0      9.0      1.0
# 35  0158  2.689273e+06  1.512679e+06  609.0     31.0      1.0
# 36  1974  2.685817e+06  1.514872e+06  793.0     26.0      1.0
# 37  0141  2.640734e+06  1.529502e+06  544.0     18.0      1.0
# 38  0263  2.653715e+06  1.514116e+06   70.0     48.0      1.0
# 39  0263  2.653715e+06  1.514116e+06   70.0     48.0      1.0
# 40  098A  2.697512e+06  1.505540e+06  375.0      9.0      1.0
# 41  098A  2.697512e+06  1.505540e+06  375.0      9.0      1.0
# 42  0976  2.687161e+06  1.510964e+06   58.0     31.0    224.0
# 43  1248  2.673587e+06  1.519593e+06  779.0     46.0      1.0
# 44  4642  2.667467e+06  1.512943e+06   75.0     39.0      1.0
# 45  370A  2.673459e+06  1.509162e+06   75.0     39.0      1.0
# 46  4708  2.661630e+06  1.524840e+06   75.0     39.0      1.0
# 47  3428  2.664837e+06  1.522077e+06   75.0     39.0      1.0
# 48  0791  2.670041e+06  1.530999e+06  565.0     21.0      1.0
# 49   NaN  2.662684e+06  1.542692e+06    NaN      NaN      NaN

# %% [markdown]
# ### No están todos los shapes :(
# ### pero no faltan tantos :)

# %%
ageeml = pd.read_csv("data/AGEEML_NL.csv")

# %%
ageeml.head()
# Out:
#         Mapa  Cve_Ent     Nom_Ent Nom_Abr  Cve_Mun  Nom_Mun  Cve_Loc  \
# 0  190010001       19  Nuevo León      NL        1  Abasolo        1
# 1  190010008       19  Nuevo León      NL        1  Abasolo        8
# 2  190010009       19  Nuevo León      NL        1  Abasolo        9
# 3  190010011       19  Nuevo León      NL        1  Abasolo       11
# 4  190010012       19  Nuevo León      NL        1  Abasolo       12
#
#                            Nom_Loc Ámbito         Latitud         Longitud  \
# 0                          Abasolo      U  25°56´43.215N"  100°23´59.958W"
# 1                        La Gloria      R  25°56´14.103N"  100°22´48.748W"
# 2                      Los Ligeros      R  25°55´57.079N"  100°23´39.742W"
# 3                       La Muralla      R  25°56´18.560N"  100°23´52.699W"
# 4  Seis de Enero (Las Bugambilias)      R  25°56´59.312N"  100°24´26.446W"
#
#    Lat_Decimal  Lon_Decimal  Altitud Cve_Carta  Pob_Total  Pob_Masculina  \
# 0    25.945338  -100.399988      502    G14C15       1976           1005
# 1    25.937251  -100.380208      499    G14C15          7              0
# 2    25.932522  -100.394373      504    G14C15          3              0
# 3    25.938489  -100.397972      500    G14C15          4              0
# 4    25.949809  -100.407346      509    G14C15          0              0
#
#    Pob_Femenina  Total De Viviendas Habitadas
# 0           971                           529
# 1             0                             1
# 2             0                             1
# 3             0                             2
# 4             0                             0

# %%
ageeml.dtypes
# Out:
# Mapa                              int64
# Cve_Ent                           int64
# Nom_Ent                          object
# Nom_Abr                          object
# Cve_Mun                           int64
# Nom_Mun                          object
# Cve_Loc                           int64
# Nom_Loc                          object
# Ámbito                           object
# Latitud                          object
# Longitud                         object
# Lat_Decimal                     float64
# Lon_Decimal                     float64
# Altitud                           int64
# Cve_Carta                        object
# Pob_Total                         int64
# Pob_Masculina                     int64
# Pob_Femenina                      int64
# Total De Viviendas Habitadas      int64
# dtype: object

# %%
merged = df.merge(ageeml[["Cve_Mun", "Nom_Mun", "Cve_Loc"]], 
                  right_on=["Cve_Mun", "Cve_Loc"], left_on=["cve_mun", "cve_loc"], how="left")

# %%
print(merged.shape)
# Out:
# (2114, 22)

# %%
merged.head(7)
# Out:
#    year        date        lat         lon  \
# 0  2015  2015-10-12  25.617672 -100.259318
# 1  2015  2015-10-02  25.632075 -100.286088
# 2  2015  2015-10-01  25.675784 -100.475788
# 3  2015  2015-09-24  25.657586 -100.322029
# 4  2015  2015-09-24  25.683207 -100.305650
# 5  2015  2015-09-23  25.777561 -100.410404
# 6  2015  2015-09-18  25.702387 -100.330845
#
#                                     news  cassualties  \
# 0          Persiguen y ejecutan a hombre          1.0
# 1  Ejecutan a uno en plaza en Garza Sada          1.0
# 2           Lo ejecutan frente a su casa          1.0
# 3             Lo esperan para ejecutarlo          1.0
# 4  Matan a 2 clientes en ataque 13 a bar          2.0
# 5      Asesinan a ex reo de tres balazos          1.0
# 6  Ejecutan a uno en la Col. Garza Nieto          1.0
#
#                                                  url  \
# 0  http://www.elnorte.com/aplicaciones/articulo/d...
# 1  http://www.elnorte.com/aplicaciones/articulo/d...
# 2  http://www.elnorte.com/aplicaciones/articulo/d...
# 3  http://www.elnorte.com/aplicaciones/articulo/d...
# 4  http://www.elnorte.com/aplicaciones/articulo/d...
# 5  http://www.elnorte.com/aplicaciones/articulo/d...
# 6  http://www.elnorte.com/aplicaciones/articulo/d...
#
#                        neighborhood  \
# 0                EJIDAL LOS REMATES
# 1             REVOLUCION PROLETARIA
# 2  HDA SANTA CATARINA (FOMERREY 29)
# 3                     INDEPENDENCIA
# 4               CENTRO DE MONTERREY
# 5                        LA ALIANZA
# 6                      PEDRO LOZANO
#
#                                        point  clave_mun  ...  \
# 0   [2673990.068792671,  1508739.2403134028]       39.0  ...
# 1   [2671295.4132258967,  1510294.803596502]       39.0  ...
# 2  [2652285.5673206407,  1514899.6189773784]       48.0  ...
# 3   [2667670.5901743174,  1513064.839283476]       39.0  ...
# 4  [2669273.8077375377,  1515908.7290589423]       39.0  ...
# 5   [2658693.510923911,  1526191.7772835381]       39.0  ...
# 6  [2666732.2379076034,  1517993.7998131234]       39.0  ...
#
#                  nom_loc  ageb             x             y     r  cve_mun  \
# 0              Monterrey  3729  2.673990e+06  1.508739e+06  75.0     39.0
# 1              Monterrey  4727  2.671295e+06  1.510295e+06  75.0     39.0
# 2  Ciudad Santa Catarina  0545  2.652286e+06  1.514900e+06  70.0     48.0
# 3              Monterrey  1968  2.667671e+06  1.513065e+06  75.0     39.0
# 4              Monterrey  1281  2.669274e+06  1.515909e+06  75.0     39.0
# 5              Monterrey  5015  2.658694e+06  1.526192e+06  75.0     39.0
# 6              Monterrey  0921  2.666732e+06  1.517994e+06  75.0     39.0
#
#    cve_loc  Cve_Mun         Nom_Mun  Cve_Loc
# 0      1.0     39.0       Monterrey      1.0
# 1      1.0     39.0       Monterrey      1.0
# 2      1.0     48.0  Santa Catarina      1.0
# 3      1.0     39.0       Monterrey      1.0
# 4      1.0     39.0       Monterrey      1.0
# 5      1.0     39.0       Monterrey      1.0
# 6      1.0     39.0       Monterrey      1.0
#
# [7 rows x 22 columns]

# %%
merged = merged.drop(["r", "Cve_Mun", "Cve_Loc", "point", 
                      "clave_loc", "clave_mun", "ageb", "nom_mun"], axis=1)

# %%
merged.columns
# Out:
# Index(['year', 'date', 'lat', 'lon', 'news', 'cassualties', 'url',
#        'neighborhood', 'nom_loc', 'x', 'y', 'cve_mun', 'cve_loc', 'Nom_Mun'],
#       dtype='object')

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2114 entries, 0 to 2113
# Data columns (total 14 columns):
# year            2114 non-null int64
# date            2114 non-null object
# lat             2114 non-null float64
# lon             2114 non-null float64
# news            2114 non-null object
# cassualties     2114 non-null float64
# url             2114 non-null object
# neighborhood    1860 non-null object
# x               2114 non-null float64
# y               2114 non-null float64
# cve_mun         1939 non-null float64
# nom_mun         1939 non-null object
# cve_loc         1939 non-null float64
# nom_loc         1939 non-null object
# dtypes: float64(7), int64(1), object(6)
# memory usage: 247.7+ KB

# %%
merged.columns = ['year', 'date', 'lat', 'lon', 'news', 'cassualties', 'url',
       'neighborhood', 'nom_loc', 'x', 'y', 'cve_mun', 'cve_loc', 'nom_mun']

# %%
merged = merged[['year', 'date', 'lat', 'lon', 'news', 'cassualties', 'url',
       'neighborhood', 'x', 'y', 'cve_mun', 'nom_mun', 'cve_loc', 'nom_loc']]

# %%
merged["cve_mun"] = merged["cve_mun"].fillna('')
merged["cve_mun"] = merged["cve_mun"].astype(str)
merged["cve_mun"] = merged["cve_mun"].str.split('.')
merged["cve_mun"] = merged["cve_mun"].str[0]

# %%
merged["cve_loc"] = merged["cve_loc"].fillna('')
merged["cve_loc"] = merged["cve_loc"].astype(str)
merged["cve_loc"] = merged["cve_loc"].str.split('.')
merged["cve_loc"] = merged["cve_loc"].str[0]

# %%
merged.to_csv("data/crime_inegi_localidades.csv", index=False)
